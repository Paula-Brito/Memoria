# %%
import xarray as xr
import numpy as np
import matplotlib.pylab as plt
import os
import scipy.interpolate
from array import *
import numpy
import matplotlib.cm as cm
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.colors as mcolors
# Out:
# /home/paula/anaconda3/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# /home/paula/anaconda3/lib/python3.7/site-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %% [markdown]
# # Deformación Inicial Escenarios
# ## Graficando level03

# %%
#read_dictionary=np.load(os.getcwd()+'/'+'ArchivosNati/000300/level01-float16.npy',allow_pickle=True).item()
#read_dictionary.keys()

ruta_level03='/home/paula/Documentos/Memoria/HySea/UTFSM-IniciacionTsunami-20200505T151943Z-001/UTFSM-IniciacionTsunami/ejemplo_chile/Escenarios_corridos/Escenarios/res_level03_sce400-003/'
ruta = '/home/paula/Documentos/Memoria/HySea/UTFSM-IniciacionTsunami-20200505T151943Z-001/UTFSM-IniciacionTsunami/ejemplo_chile/Escenarios_corridos/'#os.getcwd()+'/'
carpeta='Escenarios/resul_series_sce400/'


for i in range(200,220):
    
    if np.any(i <  int(10)) and np.any(i>=0):
        fold_escenario='00000'+str(i)+'/'
    if np.any(i < int(100)) and np.any(i >= int(10)):
        fold_escenario='0000'+str(i)+'/'
    if np.any(i >= int(100)):
        fold_escenario='000'+str(i)+'/'
    
    runs_level03_coquimbo=np.load(ruta_level03+fold_escenario+'level03coq-float16.npy',allow_pickle=True).item()
    runs_level03_valpo=np.load(ruta_level03+fold_escenario+'level03q2valp-float16.npy',allow_pickle=True).item()
    
#coquimbo
    lon_coquimbo=runs_level03_coquimbo['lon']
    lat_coquimbo=runs_level03_coquimbo['lat']
    #deformed_bathy_coquimbo=runs_level03_coquimbo['deformed_bathy']
    original_bathy_coquimbo=runs_level03_coquimbo['original_bathy']
    #def_inicial_coquimbo=[]
    eta_coquimbo=runs_level03_coquimbo['eta0']
    
    #for j in range(len(deformed_bathy_coquimbo)):
    #    def_inicial_coquimbo.append(deformed_bathy_coquimbo[j]-original_bathy_coquimbo[j])
    
    figure=plt.figure(figsize=(10,8), dpi=100)
    eta_coquimbo[np.where(original_bathy_coquimbo<0.0)] = np.NaN
    original_bathy_coquimbo[np.where(original_bathy_coquimbo>0.0)] = np.NaN
    
    minz=-1
    maxz=2
    curvas=100
    delta = (maxz-minz)/curvas
    #eta_coquimbo[eta_coquimbo>maxz] = maxz
    eta_coquimbo[eta_coquimbo<minz] = minz
    contour=np.linspace(minz,maxz,curvas)
      
    map = figure.add_subplot(111)
    
    
    map.contourf(lon_coquimbo,lat_coquimbo,-original_bathy_coquimbo,10,cmap=cm.get_cmap('copper'))
    cs = map.contourf(lon_coquimbo,lat_coquimbo,eta_coquimbo,curvas,alpha=.9,cmap=cm.get_cmap('jet'))#cmap=inundation_cmap,alpha=.9)
        
    plt.gca().set_aspect('equal', adjustable='box')
    plt.xlabel('LONGITUDE')
    plt.ylabel('LATITUDE')
    plt.title('Deformación inicial Coquimbo '+fold_escenario)
    
    divider = make_axes_locatable(plt.gca())
    cax = divider.append_axes("right", size="5%", pad=0.1)
    cb=figure.colorbar(cs,format='%.2f',cax=cax)
    cb.set_label('METERS')
    
    #plt.contour(lon_coquimbo,lat_coquimbo,def_inicial_coquimbo, 80, linewidths=0.2, colors='k')
    #plt.contourf(lon_coquimbo,lat_coquimbo,def_inicial_coquimbo, 50,cmap=cmap,
    #                    vmax=max(def_inicial_coquimbo), vmin=-max(def_inicial_coquimbo),zorder =1)
    
    #figure.savefig(ruta+carpeta+fold_escenario+'Def_inicial_coquimbo_level03_'+fold_escenario.split('/')[0]+ '.png', bbox_inches='tight', dpi=600)
    figure.savefig(ruta+'Escenarios/Def_inicial_level03/'+'Def_inicial_coquimbo_level03_'+fold_escenario.split('/')[0]+ '.png', bbox_inches='tight', dpi=600)

    #plt.show()
    plt.cla()
    plt.close()
    
#valpo    
    lon_valpo=runs_level03_valpo['lon']
    lat_valpo=runs_level03_valpo['lat']
    #deformed_bathy_valpo=runs_level03_valpo['deformed_bathy']
    original_bathy_valpo=runs_level03_valpo['original_bathy']
    def_inicial_valpo=[]
    eta_valpo=runs_level03_valpo['eta0']
    
    #for j in range(len(deformed_bathy_valpo)):
    #    def_inicial_valpo.append(deformed_bathy_valpo[j]-original_bathy_valpo[j])
    
    #lon_level03_valpo.append(lon_valpo)
    #lat_level03_valpo.append(lat_valpo)
    #deformed_bathy_level03_valpo.append(deformed_bathy_valpo)
    
    figure=plt.figure(figsize=(10,8), dpi=100)
    eta_valpo[np.where(original_bathy_valpo<0.0)] = np.NaN
    original_bathy_valpo[np.where(original_bathy_valpo>0.0)] = np.NaN
    
    minz=-1
    maxz=2
    curvas=100
    delta = (maxz-minz)/curvas
    #eta_valpo[eta_valpo>maxz] = maxz
    eta_valpo[eta_valpo<minz] = minz
    contour=np.linspace(minz,maxz,curvas)
    
    map = figure.add_subplot(111)
    
    map.contourf(lon_valpo,lat_valpo,-original_bathy_valpo,10,cmap=cm.get_cmap('copper'))
    cs = map.contourf(lon_valpo,lat_valpo,eta_valpo,curvas,alpha=.9,cmap=cm.get_cmap('jet'))#cmap=inundation_cmap,alpha=.9)

    plt.gca().set_aspect('equal', adjustable='box')
    plt.xlabel('LONGITUDE')
    plt.ylabel('LATITUDE')
    plt.title('Deformación inicial Valparaíso '+fold_escenario)
    
    divider = make_axes_locatable(plt.gca())
    cax = divider.append_axes("right", size="5%", pad=0.1)
    cb=figure.colorbar(cs,format='%.2f',cax=cax)
    cb.set_label('METERS')
    #plt.contour(lon_valpo,lat_valpo,deformed_bathy_valpo, 80, linewidths=0.2, colors='k')
    #plt.contourf(lon_valpo,lat_valpo,deformed_bathy_valpo, 50,cmap=cmap,
    #                    vmax=max(deformed_bathy_valpo), vmin=-max(deformed_bathy_valpo),zorder =1)
    
    #figure.savefig(ruta+carpeta+fold_escenario+'Def_inicial_valpo_level03'+fold_escenario.split('/')[0]+ '.png', bbox_inches='tight', dpi=600)
    figure.savefig(ruta+'Escenarios/Def_inicial_level03/'+'Def_inicial_valpo_level03'+fold_escenario.split('/')[0]+ '.png', bbox_inches='tight', dpi=600)
    plt.cla()
    plt.close()

    print(i)
# Out:
# 200
# 201
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# 211
# 212
# 213
# 214
# 215
# 216
# 217
# 218
# 219

# %% [markdown]
# ## Graficando level01

# %%
ruta_level01='/home/paula/Documentos/Memoria/HySea/UTFSM-IniciacionTsunami-20200505T151943Z-001/UTFSM-IniciacionTsunami/ejemplo_chile/Escenarios_corridos/Escenarios/res_level01_sce400/'
ruta = '/home/paula/Documentos/Memoria/HySea/UTFSM-IniciacionTsunami-20200505T151943Z-001/UTFSM-IniciacionTsunami/ejemplo_chile/Escenarios_corridos/'#os.getcwd()+'/'
carpeta='Escenarios/resul_series_sce400/'
for i in range(248,350):
    
    if np.any(i <  int(10)) and np.any(i>=0):
        fold_escenario='00000'+str(i)+'/'
    if np.any(i < int(100)) and np.any(i >= int(10)):
        fold_escenario='0000'+str(i)+'/'
    if np.any(i >= int(100)):
        fold_escenario='000'+str(i)+'/'
    
    runs_level01=np.load(ruta_level01+fold_escenario+'level01-float16.npy',allow_pickle=True).item()
    
    lon=runs_level01['lon']
    lat=runs_level01['lat']
    #deformed_bathy=runs_level01['deformed_bathy']
    original_bathy=runs_level01['original_bathy']
    #def_inicial=[]
    #eta_coquimbo=runs_level03_coquimbo['eta0']
    
    #for j in range(len(deformed_bathy)):
    #    def_inicial.append(deformed_bathy[j]-original_bathy[j])
    
    eta=runs_level01['eta0']
    #lon_level03_coquimbo.append(lon_coquimbo)
    #lat_level03_coquimbo.append(lat_coquimbo)
    #deformed_bathy_level03_coquimbo.append(deformed_bathy_coquimbo)
    
    figure=plt.figure(figsize=(10,8), dpi=100)
    eta[np.where(original_bathy<0.0)] = np.NaN
    original_bathy[np.where(original_bathy>0.0)] = np.NaN
    
    minz=-1
    maxz=10
    curvas=100
    delta = (maxz-minz)/curvas
    #eta[eta>maxz] = maxz
    eta[eta<minz] = minz
    contour=np.linspace(minz,maxz,curvas)
      
    map = figure.add_subplot(111)
    
    
    map.contourf(lon,lat,-original_bathy,10,cmap=cm.get_cmap('copper'))
    cs = map.contourf(lon,lat,eta,curvas,alpha=.9,cmap=cm.get_cmap('jet'))#cmap=inundation_cmap,alpha=.9)
        
    plt.gca().set_aspect('equal', adjustable='box')
    plt.xlabel('LONGITUDE')
    plt.ylabel('LATITUDE')
    plt.title('Deformación Inicial '+fold_escenario.split('/')[0])
    divider = make_axes_locatable(plt.gca())
    cax = divider.append_axes("right", size="5%", pad=0.1)
    cb=figure.colorbar(cs,format='%.2f',cax=cax)
    cb.set_label('METERS')
    
    #plt.contour(lon_coquimbo,lat_coquimbo,def_inicial_coquimbo, 80, linewidths=0.2, colors='k')
    #plt.contourf(lon_coquimbo,lat_coquimbo,def_inicial_coquimbo, 50,cmap=cmap,
    #                    vmax=max(def_inicial_coquimbo), vmin=-max(def_inicial_coquimbo),zorder =1)
    
    #figure.savefig(ruta+carpeta+fold_escenario+'Def_inicial_level01_'+fold_escenario.split('/')[0]+ '.png', bbox_inches='tight', dpi=600)
    figure.savefig(ruta+'Escenarios/Def_inicial_level01/'+'Def_inicial_level01_'+fold_escenario.split('/')[0]+ '.png', bbox_inches='tight', dpi=600)

    plt.cla()
    plt.close()
    

    print(i)
# Out:
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 297
# 298
# 299
# 300
# 301
# 302
# 303
# 304
# 305
# 306
# 307
# 308
# 309
# 310
# 311
# 312
# 313
# 314
# 315
# 316
# 317
# 318
# 319
# 320
# 321
# 322
# 323
# 324
# 325
# 326
# 327
# 328
# 329
# 330
# 331
# 332
# 333
# 334
# 335
# 336
# 337
# 338
# 339
# 340
# 341
# 342
# 343
# 344
# 345
# 346
# 347
# 348
# 349
